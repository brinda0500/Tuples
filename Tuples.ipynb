# %%
tup= ('cse','it','mech')
print(tup)
tup1=(1,23,4,5,5,6)
print(tup1)
tup2="abc","def"
print(tup2)
# Out:
# ('cse', 'it', 'mech')
# (1, 23, 4, 5, 5, 6)
# ('abc', 'def')

# %%
tup1 = ()
print(tup1)
# Out:
# ()

# %%
tup1 = (24)
print(tup1)
# Out:
# 24

# %%
tup= ('cse','it','mech','ece','electrical')
print(tup[0])
print(tup[2])
print(tup[2:5])
# Out:
# cse
# mech
# ('mech', 'ece', 'electrical')

# %%
tup1= ('cse','it','mech','ece','electrical')
 print(tup1)

del(tup1)
 print(tup1)
# Out:
#   File "<ipython-input-6-3c9d0f6fee29>", line 2
#     print(tup1)
#     ^
# IndentationError: unexpected indent

# %%
tup1= ('cse','it','mech','ece','electrical')
print(tup1)
tup2= ('brinda','abi','ananya')
print(tup2)


tup3=tup1+tup2
print(tup3)
# Out:
# ('cse', 'it', 'mech', 'ece', 'electrical')
# ('brinda', 'abi', 'ananya')
# ('cse', 'it', 'mech', 'ece', 'electrical', 'brinda', 'abi', 'ananya')

# %%
tup1= ('cse','it','mech','ece','electrical')
print(tup1)

print("value at 3rd loc= ",tup1[3])

tup1[3]="Brinda" #not allowed
print("UPDATED value at 3rd loc= ",tup1[3])
# Out:
# ('cse', 'it', 'mech', 'ece', 'electrical')
# value at 3rd loc=  ece
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-762e2c646b61> in <module>()
#       4 print("value at 3rd loc= ",tup1[3])
#       5
# ----> 6 tup1[3]="Brinda" #not allowed
#       7 print("UPDATED value at 3rd loc= ",tup1[3])
#
# TypeError: 'tuple' object does not support item assignment

# %%
tup1= ('cse','it','mech','ece','electrical')
print(tup1)
tup2= ('brinda','ananya','abi')
print(tup2)
a=len(tup1)
b=len(tup2)
print(a)
print(b)

print(len(tup1))
# Out:
# ('cse', 'it', 'mech', 'ece', 'electrical')
# ('brinda', 'ananya', 'abi')
# 5
# 3
# 5

# %%
tup1= ('cse','it','mech','ece','electrical')
print(tup1)
tup2= ('brinda','abi','ananya')
print(tup2)


print(max(tup1))
# Out:
# ('cse', 'it', 'mech', 'ece', 'electrical')
# ('brinda', 'abi', 'ananya')
# mech
